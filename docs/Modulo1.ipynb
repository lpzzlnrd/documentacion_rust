// %% [markdown]
// Modulo 1 Fundamentos
//
// Variables y mutabilidad
// let x = 5 crea una variable inmutable.
// let mut x = 5 permite modificar el valor.
//
// Funciones
// fn suma(a: i32, b: i32) -> i32 { a + b }
//
// Control de flujo
// if else para condiciones.
// for y while para iteracion.
// match para patrones.
