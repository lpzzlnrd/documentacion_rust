// %% [markdown]
// Documentacion de Rust
// Autor Leonardo Correa
//
// Objetivo
// Presentar una vista rapida del lenguaje y del flujo con Cargo.
//
// Puntos clave
// Rust prioriza seguridad y rendimiento.
// El compilador ayuda a detectar errores en tiempo de compilacion.
// Cargo administra dependencias y tareas comunes.
